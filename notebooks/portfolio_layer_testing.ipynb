# %%
import sys
import os

# Ensure project root is in path
sys.path.append(os.path.abspath(".."))

import model.portfolio as portfolio
from model.policy import Policy
from model.assumptions import Assumptions

assumptions = Assumptions()

policies = [
    Policy(age=30, term=20, sum_assured=100000, premium=500),
    Policy(age=40, term=15, sum_assured=80000, premium=600)
]

result = portfolio.value_portfolio(policies, assumptions)

print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import model.portfolio as portfolio
#       2 from model.policy import Policy
#       3 from model.assumptions import Assumptions
#       4
#
# ModuleNotFoundError: No module named 'model'
